# %%
import pandas as pd
# !pip install openpyxl
# !pip install Jinja2

# %%
import pandas as pd

# Load the Excel file into a Pandas DataFrame
Data_df = pd.read_excel("/Users/rajeshwarrao/Downloads/Segmentation.xlsx", sheet_name="Data_1",header=0)

# Print the DataFrame
#print(Data_df[["S.N","Name","ID","Age group","Sex","Status (Single/ partner)","Residence Zip Code","Score_Demo"]])

display(Data_df)

display(Data_df[["S.N","Name","ID","Age group","Sex","Status (Single/ partner)","Residence Zip Code","Score_Demo"]])

display(Data_df[['Name']].describe())
# Out:
#      S.N                   Name     ID Age group Sex Status (Single/ partner)  \
# 0      1    Frist_1 Last name_1  NM001  below 30   M                   Single
# 1      2    Frist_2 Last name_2  NM002     30-45   F                  Partner
# 2      3    Frist_1 Last name_2  NM003     45-60   F                  Partner
# 3      4    Frist_2 Last name_3  NM004      60 +   F                  Partner
# 4      5    Frist_1 Last name_3  NM005  below 30   M                   Single
# ..   ...                    ...    ...       ...  ..                      ...
# 577  578  Frist_2 Last name_290  NM578     30-45   F                  Partner
# 578  579  Frist_1 Last name_290  NM579     45-60   M                  Partner
# 579  580  Frist_2 Last name_291  NM580      60 +   F                   Single
# 580  581  Frist_1 Last name_291  NM581  below 30   M                   Single
# 581  582  Frist_2 Last name_292  NM582     30-45   M                  Partner
#
# ...

# %%
import pandas as pd

# Load the Excel file into a Pandas DataFrame
Weights_df = pd.read_excel("/Users/rajeshwarrao/Downloads/Segmentation.xlsx", sheet_name="Scores",header=0)
display(Weights_df[["Segment"]])
# Print the DataFrame
display(Weights_df.loc[Weights_df["Segment"]=="Demographics"])
# Out:
#            Segment
# 0     Demographics
# 1     Demographics
# 2     Demographics
# 3     Demographics
# 4     Demographics
# ..             ...
# 73  Social factors
# 74  Social factors
# 75  Social factors
# 76  Social factors
# 77  Social factors
#
# [78 rows x 1 columns]
#         Segment                  Variable  Range_Start  Range_End  \
# 0  Demographics                       Age          0.0       29.0
# 1  Demographics                       Age         30.0       45.0
# 2  Demographics                       Age         45.0       59.0
# 3  Demographics                       Age         60.0        NaN
# 4  Demographics                       Sex          NaN        NaN
# 5  Demographics                       Sex          NaN        NaN
# 6  Demographics  Status (Single/ partner)          NaN        NaN
# 7  Demographics  Status (Single/ partner)          NaN        NaN
# 8  Demographics        Residence Zip Code          NaN        NaN
# ...

# %%
import pandas as pd

# Load the Excel file into a Pandas DataFrame
Data_df = pd.read_excel("/Users/rajeshwarrao/Downloads/Segmentation.xlsx", sheet_name="Data_1",header=0)

# Print the DataFrame
#print(Data_df[["S.N","Name","ID","Age group","Sex","Status (Single/ partner)","Residence Zip Code","Score_Demo"]])

display(Data_df)

display(Data_df[["S.N","Name","ID","Age group","Sex","Status (Single/ partner)","Residence Zip Code","Score_Demo"]])

display(Data_df[['Name']].describe())



# Load the Excel file into a Pandas DataFrame
Weights_df = pd.read_excel("/Users/rajeshwarrao/Downloads/Segmentation.xlsx", sheet_name="Scores",header=0)
display(Weights_df[["Segment"]])
# Print the DataFrame
display(Weights_df.loc[Weights_df["Segment"]=="Demographics"])


#display(Weights_df.loc[(Weights_df["Segment"]=="Demographics") & (Weights_df["Variable "]=="Age")])


Data_df['Age group']=Data_df['Age group'].str.strip()
Data_df["Residence Zip Code"]=Data_df["Residence Zip Code"].str.strip()
Weights_df["Category"]=Weights_df["Category"].str.strip()
Weights_df_age=Weights_df.loc[(Weights_df["Segment"]=="Demographics") & (Weights_df["Variable"]=="Age")]
Weights_df_age['Age group']=Weights_df_age['Range'].str.strip()
display(Weights_df_age)
demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
display(demo_age_scores_df)
demo_age_scores_df['Score_Demo_Age']=demo_age_scores_df['Score_Weight']
demo_age_scores_df=demo_age_scores_df.drop("Score_Weight",axis=1)
display(demo_age_scores_df.count())
display(Data_df)

'''
#display(demo_scores_df) 
#display(Weights_df.loc[(Weights_df["Segment"]=="Demographics") & (Weights_df["Variable "]=="Age")])
demo_pin_scores_df=Data_df.merge(Weights_df.loc[(Weights_df["Segment"]=="Demographics") & (Weights_df["Variable"]=="Residence Zip Code")], left_on='Residence Zip Code',right_on='Category',how='outer')[['S.N','Score_Weight']]
demo_pin_scores_df['Score_Demo_Pin']=demo_pin_scores_df['Score_Weight']
demo_pin_scores_df=demo_pin_scores_df.drop("Score_Weight",axis=1)
display(demo_pin_scores_df)


demo_sex_scores_df=Data_df.merge(Weights_df.loc[(Weights_df["Segment"]=="Demographics") & (Weights_df["Variable"]=="Sex")], left_on='Sex',right_on='Category')[['S.N','Score_Weight']]
demo_sex_scores_df['Score_Demo_Sex']=demo_sex_scores_df['Score_Weight']
demo_sex_scores_df=demo_sex_scores_df.drop("Score_Weight",axis=1)
display(demo_sex_scores_df)

display(Weights_df.loc[(Weights_df["Segment"]=="Demographics") & (Weights_df["Variable"]=="Status (Single/ partner)")])
demo_status_scores_df=Data_df.merge(Weights_df.loc[(Weights_df["Segment"]=="Demographics") & (Weights_df["Variable"]=="Status (Single/ partner)")], left_on='Status (Single/ partner)',right_on='Category',how='outer')[['S.N','Score_Weight']]
demo_status_scores_df['Score_Demo_Status']=demo_status_scores_df['Score_Weight']
demo_status_scores_df=demo_status_scores_df.drop("Score_Weight",axis=1)
print(demo_status_scores_df)


#demo_scores_final_df=demo_scores_df.join(demo_scores_pin_df, on ='S.N')['S.N','Score_Demo_Pin']
#display(demo_scores_final_df)
#demo_scores_df=demo_age_scores_df.merge(demo_pin_scores_df, on='S.N')
#demo_scores_df=demo_sex_scores_df.merge(demo_scores_df, on='S.N')
#demo_scores_df=demo_status_scores_df.merge(demo_scores_df, on='S.N')

#display(demo_scores_df)

#display(demo_scores_final_df)


Data_df=Data_df.merge(demo_scores_df, on='S.N',how='outer')
display(Data_df["Score_Demo_Status"])
Data_df["Score_Demo"]=Data_df["Score_Demo_Status"]+Data_df["Score_Demo_Sex"]+Data_df["Score_Demo_Age"]+Data_df["Score_Demo_Pin"]

display(Data_df)
                                           
                                           '''
# Out:
#      S.N                   Name     ID Age group Sex Status (Single/ partner)  \
# 0      1    Frist_1 Last name_1  NM001  below 30   M                   Single
# 1      2    Frist_2 Last name_2  NM002     30-45   F                  Partner
# 2      3    Frist_1 Last name_2  NM003     45-60   F                  Partner
# 3      4    Frist_2 Last name_3  NM004      60 +   F                  Partner
# 4      5    Frist_1 Last name_3  NM005  below 30   M                   Single
# ..   ...                    ...    ...       ...  ..                      ...
# 577  578  Frist_2 Last name_290  NM578     30-45   F                  Partner
# 578  579  Frist_1 Last name_290  NM579     45-60   M                  Partner
# 579  580  Frist_2 Last name_291  NM580      60 +   F                   Single
# 580  581  Frist_1 Last name_291  NM581  below 30   M                   Single
# 581  582  Frist_2 Last name_292  NM582     30-45   M                  Partner
#
# ...

# %%
display(Weights_df.loc[(Weights_df['Variable']=='Sex')&(Weights_df['Category']=='F')])
# Out:
#         Segment Variable  Range_Start  Range_End Category Range  Score_Weight
# 4  Demographics      Sex          NaN        NaN        F   NaN            20

# %%
import pandas as pd

# Load the Excel file into a Pandas DataFrame
Data_df = pd.read_excel("/Users/rajeshwarrao/Downloads/Segmentation.xlsx", sheet_name="Data_1",header=0)

# Print the DataFrame
#print(Data_df[["S.N","Name","ID","Age group","Sex","Status (Single/ partner)","Residence Zip Code","Score_Demo"]])

display(Data_df)
display(Data_df['Drug abuse'])

display(Data_df[["S.N","Name","ID","Age group","Sex","Status (Single/ partner)","Residence Zip Code","Score_Demo"]])

display(Data_df[['Name']].describe())



# Load the Excel file into a Pandas DataFrame
Weights_df = pd.read_excel("/Users/rajeshwarrao/Downloads/Segmentation.xlsx", sheet_name="Scores",header=0)
display(Weights_df[["Segment"]])
# Print the DataFrame
display(Weights_df.loc[Weights_df["Segment"]=="Demographics"])


#display(Weights_df.loc[(Weights_df["Segment"]=="Demographics") & (Weights_df["Variable "]=="Age")])


#Data_df['Age group']=Data_df['Age group'].str.strip()
#Data_df["Residence Zip Code"]=Data_df["Residence Zip Code"].str.strip()
#Weights_df["Category"]=Weights_df["Category"].str.strip()
#Weights_df_age=Weights_df.loc[(Weights_df["Segment"]=="Demographics") & (Weights_df["Variable"]=="Age")]
#Weights_df_age['Age group']=Weights_df_age['Range'].str.strip()
#display(Weights_df_age)
#demo_age_scores_df = pd.merge(Data_df, Weights_df_age, on="Age group", how="outer")
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
#display(demo_age_scores_df)
#demo_age_scores_df['Score_Demo_Age']=demo_age_scores_df['Score_Weight']
#demo_age_scores_df=demo_age_scores_df.drop("Score_Weight",axis=1)
#display(demo_age_scores_df.count())

#display(demo_age_scores_df.loc[(demo_age_scores_df['S.N']==4)])

#demo_age_scores_df=demo_age_scores_df[['S.N','Score_Demo_Age']]
#display(demo_age_scores_df)



'''
display(Data_df)
#display(demo_scores_df) 
#display(Weights_df.loc[(Weights_df["Segment"]=="Demographics") & (Weights_df["Variable "]=="Age")])
demo_pin_scores_df=Data_df.merge(Weights_df.loc[(Weights_df["Segment"]=="Demographics") & (Weights_df["Variable"]=="Residence Zip Code")], left_on='Residence Zip Code',right_on='Category',how='outer')[['S.N','Score_Weight']]
demo_pin_scores_df['Score_Demo_Pin']=demo_pin_scores_df['Score_Weight']
demo_pin_scores_df=demo_pin_scores_df.drop("Score_Weight",axis=1)
display(demo_pin_scores_df)


demo_sex_scores_df=Data_df.merge(Weights_df.loc[(Weights_df["Segment"]=="Demographics") & (Weights_df["Variable"]=="Sex")], left_on='Sex',right_on='Category')[['S.N','Score_Weight']]
demo_sex_scores_df['Score_Demo_Sex']=demo_sex_scores_df['Score_Weight']
demo_sex_scores_df=demo_sex_scores_df.drop("Score_Weight",axis=1)
display(demo_sex_scores_df)

display(Weights_df.loc[(Weights_df["Segment"]=="Demographics") & (Weights_df["Variable"]=="Status (Single/ partner)")])
demo_status_scores_df=Data_df.merge(Weights_df.loc[(Weights_df["Segment"]=="Demographics") & (Weights_df["Variable"]=="Status (Single/ partner)")], left_on='Status (Single/ partner)',right_on='Category',how='outer')[['S.N','Score_Weight']]
demo_status_scores_df['Score_Demo_Status']=demo_status_scores_df['Score_Weight']
demo_status_scores_df=demo_status_scores_df.drop("Score_Weight",axis=1)
print(demo_status_scores_df)


#demo_scores_final_df=demo_scores_df.join(demo_scores_pin_df, on ='S.N')['S.N','Score_Demo_Pin']
#display(demo_scores_final_df)
#demo_scores_df=demo_age_scores_df.merge(demo_pin_scores_df, on='S.N')
#demo_scores_df=demo_sex_scores_df.merge(demo_scores_df, on='S.N')
#demo_scores_df=demo_status_scores_df.merge(demo_scores_df, on='S.N')

#display(demo_scores_df)

#display(demo_scores_final_df)


Data_df=Data_df.merge(demo_scores_df, on='S.N',how='outer')
display(Data_df["Score_Demo_Status"])
Data_df["Score_Demo"]=Data_df["Score_Demo_Status"]+Data_df["Score_Demo_Sex"]+Data_df["Score_Demo_Age"]+Data_df["Score_Demo_Pin"]

display(Data_df)
'''                


### AGE
Data_df['Age group']=Data_df['Age group'].str.strip()
Data_df["Residence Zip Code"]=Data_df["Residence Zip Code"].str.strip()
Weights_df["Category"]=Weights_df["Category"].str.strip()
Weights_df_age=Weights_df.loc[(Weights_df["Segment"]=="Demographics") & (Weights_df["Variable"]=="Age")]
Weights_df_age['Age group']=Weights_df_age['Range'].str.strip()
display(Weights_df_age)
Data_df = pd.merge(Data_df, Weights_df_age, on="Age group", how="outer")
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
#display(Data_df)
Data_df['Score_Demo_Age']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
#display(Data_df.count())

#display(Data_df.loc[(Data_df['S.N']==4)])

#Data_df=Data_df[['S.N','Score_Demo_Age']]
#display(Data_df)



### SEX
Data_df['Sex']=Data_df['Sex'].str.strip()
Data_df["Residence Zip Code"]=Data_df["Residence Zip Code"].str.strip()
Weights_df["Category"]=Weights_df["Category"].str.strip()
Weights_df_sex=Weights_df.loc[(Weights_df["Segment"]=="Demographics") & (Weights_df["Variable"]=="Sex")]
Weights_df_sex['Sex']=Weights_df_sex['Category'].str.strip()
display(Weights_df_sex)
Data_df = pd.merge(Data_df, Weights_df_sex, on="Sex", how="outer")
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
#display(Data_df)
Data_df['Score_Demo_Sex']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
#display(Data_df.count())

#display(Data_df.loc[(Data_df['S.N']==4)])

#Data_df=Data_df[['S.N','Sex']]
#display(Data_df)




### Status (Single/ partner)
Data_df['Status (Single/ partner)']=Data_df['Status (Single/ partner)'].str.strip()
Data_df["Residence Zip Code"]=Data_df["Residence Zip Code"].str.strip()
Weights_df["Category"]=Weights_df["Category"].str.strip()
Weights_df_status=Weights_df.loc[(Weights_df["Segment"]=="Demographics") & (Weights_df["Variable"]=="Status (Single/ partner)")]
Weights_df_status['Status (Single/ partner)']=Weights_df_status['Category'].str.strip()
display(Weights_df_status)
Data_df = pd.merge(Data_df, Weights_df_status, on="Status (Single/ partner)", how="outer")
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
#display(Data_df)
Data_df['Score_Demo_Status']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['Category_y']==4)])
display(Data_df.loc[(Data_df['Range_y']==4)])

#display(Data_df)


#Residence Zip Code

Data_df['Residence Zip Code']=Data_df['Residence Zip Code'].str.strip()
Weights_df["Category"]=Weights_df["Category"].str.strip()
Weights_df["Variable"]=Weights_df["Variable"].str.strip()
Weights_df_zip=Weights_df.loc[(Weights_df["Segment"]=="Demographics") & (Weights_df["Variable"]=="Residence Zip Code")]
Weights_df_zip['Residence Zip Code']=Weights_df_zip['Category'].str.strip()
display(Weights_df_zip)
Data_df = pd.merge(Data_df, Weights_df_zip, on="Residence Zip Code", how="outer",suffixes=('', '_drop'))
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
#display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_Demo_Zip']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==4)])
# Out:
#      S.N                   Name     ID Age group Sex Status (Single/ partner)  \
# 0      1    Frist_1 Last name_1  NM001  below 30   M                   Single
# 1      2    Frist_2 Last name_2  NM002     30-45   F                  Partner
# 2      3    Frist_1 Last name_2  NM003     45-60   F                  Partner
# 3      4    Frist_2 Last name_3  NM004      60 +   F                  Partner
# 4      5    Frist_1 Last name_3  NM005  below 30   M                   Single
# ..   ...                    ...    ...       ...  ..                      ...
# 577  578  Frist_2 Last name_290  NM578     30-45   F                  Partner
# 578  579  Frist_1 Last name_290  NM579     45-60   M                  Partner
# 579  580  Frist_2 Last name_291  NM580      60 +   F                   Single
# 580  581  Frist_1 Last name_291  NM581  below 30   M                   Single
# 581  582  Frist_2 Last name_292  NM582     30-45   M                  Partner
#
# ...

# %%
#Occupation

Data_df['Occupation']=Data_df['Occupation'].str.strip()
Weights_df["Category"]=Weights_df["Category"].str.strip()
Weights_df["Variable"]=Weights_df["Variable"].str.strip()
Weights_df_Occupation=Weights_df.loc[(Weights_df["Segment"]=="Financial Status") & (Weights_df["Variable"]=="Occupation")]
Weights_df_Occupation['Occupation']=Weights_df_Occupation['Category'].str.strip()
display(Weights_df_Occupation)
Data_df = pd.merge(Data_df, Weights_df_Occupation, on="Occupation", how="outer",suffixes=('', '_drop'))
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
#display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_Fin_Occupation']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==4)])


#Own House

Data_df['Own House']=Data_df['Own House'].str.strip()
Weights_df["Category"]=Weights_df["Category"].str.strip()
Weights_df["Variable"]=Weights_df["Variable"].str.strip()
Weights_df_Own_House=Weights_df.loc[(Weights_df["Segment"]=="Financial Status") & (Weights_df["Variable"]=="Own House")]
Weights_df_Own_House['Own House']=Weights_df_Own_House['Category'].str.strip()
display(Weights_df_Own_House)
Data_df = pd.merge(Data_df, Weights_df_Own_House, on="Own House", how="outer",suffixes=('', '_drop'))
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
#display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_Fin_Own_House']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==4)])


#Own Car

Data_df['Own Car']=Data_df['Own Car'].str.strip()
Weights_df["Category"]=Weights_df["Category"].str.strip()
Weights_df["Variable"]=Weights_df["Variable"].str.strip()
Weights_df_Own_Car=Weights_df.loc[(Weights_df["Segment"]=="Financial Status") & (Weights_df["Variable"]=="Own Car")]
Weights_df_Own_Car['Own Car']=Weights_df_Own_Car['Category'].str.strip()
display(Weights_df_Own_Car)
Data_df = pd.merge(Data_df, Weights_df_Own_Car, on="Own Car", how="outer",suffixes=('', '_drop'))
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
#display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_Fin_Own_Car']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==4)])
# Out:
# /var/folders/dl/226xlm_d0m76nf_1nrmrhwp80000gn/T/ipykernel_84005/3038036626.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Weights_df_Occupation['Occupation']=Weights_df_Occupation['Category'].str.strip()
#              Segment    Variable  Range_Start  Range_End      Category Range  \
# 10  Financial Status  Occupation          NaN        NaN  Professional   NaN
# 11  Financial Status  Occupation          NaN        NaN      Business   NaN
# 12  Financial Status  Occupation          NaN        NaN        No Job   NaN
#
#     Score_Weight    Occupation
# 10            10  Professional
# 11            20      Business
# 12            30        No Job
# S.N                     582
# Name                    582
# ...

# %%
#FBP Level

Data_df['FBP_Level']=Data_df['FBP Level'].fillna(10000)
display(Data_df)
Weights_df["Category"]=Weights_df["Category"].str.strip()
Weights_df["Variable"]=Weights_df["Variable"].str.strip()
Weights_df_FBP_Level=Weights_df.loc[(Weights_df["Segment"]=="Financial Status") & (Weights_df["Variable"]=="FBP Level")]
Weights_df_FBP_Level['FBP_Level']=Weights_df_FBP_Level['Range_Start']
display(Weights_df_FBP_Level)
Data_df = pd.merge_asof(Data_df.sort_values('FBP_Level'), Weights_df_FBP_Level,on="FBP_Level",direction='forward',suffixes=('', '_drop'))
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df = pd.merge_asof(Data_df.sort_values('FBP_Level'), Weights_df_FBP_Level,on="FBP_Level",direction='backward',suffixes=('', '_drop'))
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_Fin_FBP_Level']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==4)])
display(Data_df)
# Out:
#      S.N                   Name     ID Age group Sex Status (Single/ partner)  \
# 0      1    Frist_1 Last name_1  NM001  below 30   M                   Single
# 1     41   Frist_1 Last name_21  NM041  below 30   M                   Single
# 2     61   Frist_1 Last name_31  NM061  below 30   M                   Single
# 3    101   Frist_1 Last name_51  NM101  below 30   M                   Single
# 4    121   Frist_1 Last name_61  NM121  below 30   M                   Single
# ..   ...                    ...    ...       ...  ..                      ...
# 577  332  Frist_2 Last name_167  NM332      60 +   F                  Partner
# 578  392  Frist_2 Last name_197  NM392      60 +   F                  Partner
# 579  452  Frist_2 Last name_227  NM452      60 +   F                  Partner
# 580  512  Frist_2 Last name_257  NM512      60 +   F                  Partner
# 581  572  Frist_2 Last name_287  NM572      60 +   F                  Partner
#
# ...

# %%
#Past medications

Data_df['Past medications']=Data_df['Past medications'].str.strip()
Weights_df["Category"]=Weights_df["Category"].str.strip()
Weights_df["Variable"]=Weights_df["Variable"].str.strip()
Weights_df_Past_medications=Weights_df.loc[(Weights_df["Segment"]=="Medication History") & (Weights_df["Variable"]=="Past medications")]
Weights_df_Past_medications['Past medications']=Weights_df_Past_medications['Category'].str.strip()
display(Data_df)
display(Weights_df_Past_medications)
Data_df = pd.merge(Data_df, Weights_df_Past_medications, on="Past medications", how="outer",suffixes=('', '_drop'))
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_MH_Past_medications']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==4)])
display(Data_df.loc[(Data_df['S.N']==4)][['Past medications','Score_MH_Past_medications']])

#display(Data_df)

Data_df_bkp=Data_df
#Formulary visist YTD

Data_df['Formulary visist YTD']=pd.to_numeric(Data_df['Formulary visist YTD'],downcast='integer')
#display(Data_df)
#display(Data_df['Formulary visist YTD'])
Weights_df["Category"]=Weights_df["Category"].str.strip()
Weights_df["Variable"]=Weights_df["Variable"].str.strip()
Weights_df_Formulary_visist=Weights_df.loc[(Weights_df["Segment"]=="Medication History") & (Weights_df["Variable"]=="Formulary visist YTD")]
Weights_df_Formulary_visist['Formulary visist YTD']=pd.to_numeric(Weights_df_Formulary_visist['Range_Start'],downcast='integer')
display(Weights_df_Formulary_visist)
Data_df = pd.merge_asof(Data_df.sort_values('Formulary visist YTD'), Weights_df_Formulary_visist, on="Formulary visist YTD", direction='backward',suffixes=('', '_drop'))
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
#display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)

Data_df = pd.merge_asof(Data_df.sort_values('Formulary visist YTD'), Weights_df_Formulary_visist, on="Formulary visist YTD", direction='forward',suffixes=('', '_drop'))
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
#display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)

Data_df['Score_MH_Formulary_visist_YTD']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==8)])
display(Data_df.loc[(Data_df['S.N']==4)])
display(Data_df.loc[(Data_df['S.N']==1)])


display(Data_df)



#Days of Therapy missed

Data_df['Days of Therapy missed']=pd.to_numeric(Data_df['Days of Therapy missed'],downcast='integer')
#display(Data_df)
#display(Data_df['Formulary visist YTD'])
Weights_df["Category"]=Weights_df["Category"].str.strip()
Weights_df["Variable"]=Weights_df["Variable"].str.strip()
Weights_df_Therapy_missed=Weights_df.loc[(Weights_df["Segment"]=="Medication History") & (Weights_df["Variable"]=="Days of Therapy missed")]
Weights_df_Therapy_missed['Days of Therapy missed']=pd.to_numeric(Weights_df_Therapy_missed['Range_Start'],downcast='integer')
display(Weights_df_Therapy_missed)
Data_df = pd.merge_asof(Data_df.sort_values('Days of Therapy missed'), Weights_df_Therapy_missed, on="Days of Therapy missed", direction='forward',suffixes=('', '_drop'))
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
#display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)


Data_df['Score_MH_Therapy_missed']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==8)])
display(Data_df.loc[(Data_df['S.N']==4)])
display(Data_df.loc[(Data_df['S.N']==1)])


display(Data_df)

Data_df_bkp=Data_df
# Out:
# /var/folders/dl/226xlm_d0m76nf_1nrmrhwp80000gn/T/ipykernel_84005/2030379537.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Weights_df_Past_medications['Past medications']=Weights_df_Past_medications['Category'].str.strip()
#      S.N                   Name     ID Age group Sex Status (Single/ partner)  \
# 0      1    Frist_1 Last name_1  NM001  below 30   M                   Single
# 1    413  Frist_1 Last name_207  NM413  below 30   M                  Partner
# 2    371  Frist_1 Last name_186  NM371     45-60   M                   Single
# 3    330  Frist_2 Last name_166  NM330     30-45   F                   Single
# 4    449  Frist_1 Last name_225  NM449  below 30   M                  Partner
# ...

# %%
Data_df=Data_df_bkp
#display(Data_df)
#Family History
#display(Data_df[Data_df['S.N'].isna()])

Data_df['Family History']=Data_df['Family History'].fillna('None').str.strip()
Weights_df["Category"]=Weights_df["Category"].fillna('None').str.strip()
Weights_df["Variable"]=Weights_df["Variable"].fillna('None').str.strip()
Weights_df_Family_History=Weights_df.loc[(Weights_df["Segment"]=="Medical History") & (Weights_df["Variable"]=="Family History")]
Weights_df_Family_History['Family History']=Weights_df_Family_History['Category'].fillna('None').str.strip()
#display(Data_df)
display(Weights_df_Family_History)
Data_df = pd.merge(Data_df, Weights_df_Family_History, on="Family History", how="outer",suffixes=('', '_drop'))
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
#display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_MH_Family_History']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
#display(Data_df.count())

#display(Data_df.loc[(Data_df['S.N']==4)])
#display(Data_df.loc[(Data_df['S.N']==4)][['Family History','Score_MedH_Family_History']])

#display(Data_df.loc[(Data_df['S.N']==3)])
#display(Data_df.loc[(Data_df['S.N']==3)][['Family History','Score_MedH_Family_History']])

#display(Data_df[Data_df['S.N'].isna()])
Data_df_temp=Data_df
Data_df_temp_bkp=Data_df_bkp

Data_df_temp_all = Data_df_temp_bkp.merge(Data_df_temp.drop_duplicates(), on=['S.N'],
                   how='left', indicator=True)

Data_df_temp_bkp_only = Data_df_temp_all[Data_df_temp_all['_merge'] == 'left_only']
print("Data_df_temp_bkp_only")
#display(Data_df_temp_bkp_only)


Data_df_temp_all = Data_df_temp_bkp.merge(Data_df_temp.drop_duplicates(), on=['S.N'],
                   how='right', indicator=True)

Data_df_temp_only = Data_df_temp_all[Data_df_temp_all['_merge'] == 'right_only']
print("Data_df_temp_only")
#display(Data_df_temp_only)

#Annual Wellness vists
Data_df['Annual Wellness vists']=Data_df['Annual Wellness vists'].str.strip()
Weights_df["Category"]=Weights_df["Category"].fillna('None').str.strip()
Weights_df["Variable"]=Weights_df["Variable"].fillna('None').str.strip()
Weights_df_Annual_Wellness_vists=Weights_df.loc[(Weights_df["Segment"]=="Medical History") & (Weights_df["Variable"]=="Annual Wellness vists")]
Weights_df_Annual_Wellness_vists['Annual Wellness vists']=Weights_df_Annual_Wellness_vists['Category'].str.strip()
display(Data_df)
display(Weights_df_Annual_Wellness_vists)
Data_df = pd.merge(Data_df, Weights_df_Annual_Wellness_vists, on="Annual Wellness vists", how="outer",suffixes=('', '_drop'))
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_MedH_Annual_Wellness_vists']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==4)])
display(Data_df.loc[(Data_df['S.N']==4)][['Annual Wellness vists','Score_MedH_Annual_Wellness_vists']])

display(Data_df.loc[(Data_df['S.N']==3)])
display(Data_df.loc[(Data_df['S.N']==3)][['Annual Wellness vists','Score_MedH_Annual_Wellness_vists']])
display(Data_df[Data_df['S.N'].isna()])
display(Data_df.loc[(Data_df['S.N']==581)])
display(Data_df.loc[(Data_df['S.N']==581)][['Annual Wellness vists','Score_MedH_Annual_Wellness_vists']])



#Known conditions
Data_df['Known conditions']=Data_df['Known conditions'].fillna('None').str.strip()
Weights_df["Category"]=Weights_df["Category"].fillna('None').str.strip()
Weights_df["Variable"]=Weights_df["Variable"].fillna('None').str.strip()
Weights_df_Known_conditions=Weights_df.loc[(Weights_df["Segment"]=="Medical History") & (Weights_df["Variable"]=="Known conditions")]
Weights_df_Known_conditions['Known conditions']=Weights_df_Known_conditions['Category'].str.strip()
display(Data_df)
display(Weights_df_Known_conditions)
Data_df = pd.merge(Data_df, Weights_df_Known_conditions, on="Known conditions", how="outer",suffixes=('', '_drop')).dropna(subset = ['S.N'])
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_MedH_Known_conditions']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==4)])
display(Data_df.loc[(Data_df['S.N']==4)][['Known conditions','Score_MedH_Known_conditions']])

display(Data_df.loc[(Data_df['S.N']==3)])
display(Data_df.loc[(Data_df['S.N']==3)][['Known conditions','Score_MedH_Known_conditions']])
display(Data_df[Data_df['S.N'].isna()])
display(Data_df.loc[(Data_df['S.N']==220)])
display(Data_df.loc[(Data_df['S.N']==220)][['Known conditions','Score_MedH_Known_conditions']])

# # of Provider visist YTD
Data_df['# of Provider visist YTD']=pd.to_numeric(Data_df['# of Provider visist YTD'],downcast='integer')
#display(Data_df)
#display(Data_df['Formulary visist YTD'])
Weights_df["Category"]=Weights_df["Category"].str.strip()
Weights_df["Variable"]=Weights_df["Variable"].str.strip()
Weights_df_Provider_visists_YTD=Weights_df.loc[(Weights_df["Segment"]=="Medical History") & (Weights_df["Variable"]=="# of Provider visist YTD")]
Weights_df_Provider_visists_YTD['# of Provider visist YTD']=pd.to_numeric(Weights_df_Provider_visists_YTD['Range_Start'],downcast='integer')
print("*****Weights_df_Provider_visists_YTD****")
display(Weights_df_Provider_visists_YTD)
print("*****Weights_df_Provider_visists_YTD****")
Data_df = pd.merge_asof(Data_df.sort_values('# of Provider visist YTD'), Weights_df_Provider_visists_YTD, on="# of Provider visist YTD", direction='forward',suffixes=('', '_drop'))
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
#display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)


Data_df['Score_MedH_Provider_visists_YTD']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())



Data_df = pd.merge_asof(Data_df.sort_values('# of Provider visist YTD'), Weights_df_Provider_visists_YTD, on="# of Provider visist YTD", direction='backward',suffixes=('', '_drop'))
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
#display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)


Data_df['Score_MedH_Provider_visists_YTD']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())


display(Data_df.loc[(Data_df['S.N']==8)])
display(Data_df.loc[(Data_df['S.N']==4)])
display(Data_df.loc[(Data_df['S.N']==1)])


display(Data_df.loc[(Data_df['S.N']==4)])
display(Data_df.loc[(Data_df['S.N']==4)][['# of Provider visist YTD','Score_MedH_Provider_visists_YTD']])

display(Data_df.loc[(Data_df['S.N']==3)])
display(Data_df.loc[(Data_df['S.N']==3)][['# of Provider visist YTD','Score_MedH_Provider_visists_YTD']])
display(Data_df[Data_df['S.N'].isna()])
display(Data_df.loc[(Data_df['S.N']==581)])
display(Data_df.loc[(Data_df['S.N']==581)][['# of Provider visist YTD','Score_MedH_Provider_visists_YTD']])

display(Data_df)

Data_df_bkp_Medical_History=Data_df
# Out:
# /var/folders/dl/226xlm_d0m76nf_1nrmrhwp80000gn/T/ipykernel_84005/207073795.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Weights_df_Family_History['Family History']=Weights_df_Family_History['Category'].fillna('None').str.strip()
#             Segment        Variable  Range_Start  Range_End  Category Range  \
# 30  Medical History  Family History          NaN        NaN  Diabetic   NaN
# 31  Medical History  Family History          NaN        NaN        BP   NaN
# 32  Medical History  Family History          NaN        NaN      Both   NaN
# 33  Medical History  Family History          NaN        NaN    Others   NaN
# 34  Medical History  Family History          NaN        NaN      None   NaN
#
#     Score_Weight Family History
# ...

# %%
Data_df=Data_df_bkp_Medical_History
#able to drive
Data_df['able to drive']=Data_df['able to drive'].str.strip()
Weights_df["Category"]=Weights_df["Category"].fillna('None').str.strip()
Weights_df["Variable"]=Weights_df["Variable"].fillna('None').str.strip()
Weights_df_able_to_drive=Weights_df.loc[(Weights_df["Segment"]=="Physical status") & (Weights_df["Variable"]=="able to drive")]
Weights_df_able_to_drive['able to drive']=Weights_df_able_to_drive['Category'].str.strip()
display(Data_df)
display(Weights_df_able_to_drive)
Data_df = pd.merge(Data_df, Weights_df_able_to_drive, on="able to drive", how="outer",suffixes=('', '_drop'))
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_PS_able_to_drive']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==4)])
display(Data_df.loc[(Data_df['S.N']==4)][['able to drive','Score_PS_able_to_drive']])

display(Data_df.loc[(Data_df['S.N']==3)])
display(Data_df.loc[(Data_df['S.N']==3)][['able to drive','Score_PS_able_to_drive']])
display(Data_df[Data_df['S.N'].isna()])
display(Data_df.loc[(Data_df['S.N']==581)])
display(Data_df.loc[(Data_df['S.N']==581)][['able to drive','Score_PS_able_to_drive']])


#can walk long distance
Data_df['can walk long distance']=Data_df['can walk long distance'].str.strip()
Weights_df["Category"]=Weights_df["Category"].fillna('None').str.strip()
Weights_df["Variable"]=Weights_df["Variable"].fillna('None').str.strip()
Weights_df_can_walk=Weights_df.loc[(Weights_df["Segment"]=="Physical status") & (Weights_df["Variable"]=="can walk long distance")]
Weights_df_can_walk['can walk long distance']=Weights_df_can_walk['Category'].str.strip()
display(Data_df)
display(Weights_df_can_walk)
Data_df = pd.merge(Data_df, Weights_df_can_walk, on="can walk long distance", how="outer",suffixes=('', '_drop'))
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_PS_can_walk']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==4)])
display(Data_df.loc[(Data_df['S.N']==4)][['can walk long distance','Score_PS_can_walk']])

display(Data_df.loc[(Data_df['S.N']==3)])
display(Data_df.loc[(Data_df['S.N']==3)][['can walk long distance','Score_PS_can_walk']])
display(Data_df[Data_df['S.N'].isna()])
display(Data_df.loc[(Data_df['S.N']==581)])
display(Data_df.loc[(Data_df['S.N']==581)][['can walk long distance','Score_PS_can_walk']])



#Dental
Data_df['Dental']=Data_df['Dental'].str.strip()
Weights_df["Category"]=Weights_df["Category"].fillna('None').str.strip()
Weights_df["Variable"]=Weights_df["Variable"].fillna('None').str.strip()
Weights_df_Dental=Weights_df.loc[(Weights_df["Segment"]=="Physical status") & (Weights_df["Variable"]=="Dental")]
Weights_df_Dental['Dental']=Weights_df_Dental['Category'].str.strip()
display(Data_df)
display(Weights_df_Dental)
Data_df = pd.merge(Data_df, Weights_df_Dental, on="Dental", how="outer",suffixes=('', '_drop')).dropna(subset = ['S.N'])
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_PS_Dental']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==4)])
display(Data_df.loc[(Data_df['S.N']==4)][['Dental','Score_PS_Dental']])

display(Data_df.loc[(Data_df['S.N']==3)])
display(Data_df.loc[(Data_df['S.N']==3)][['Dental','Score_PS_Dental']])
display(Data_df[Data_df['S.N'].isna()])
display(Data_df.loc[(Data_df['S.N']==581)])
display(Data_df.loc[(Data_df['S.N']==581)][['Dental','Score_PS_Dental']])





#Visison
Data_df['Visison']=Data_df['Visison'].str.strip()
Weights_df["Category"]=Weights_df["Category"].fillna('None').str.strip()
Weights_df["Variable"]=Weights_df["Variable"].fillna('None').str.strip()
Weights_df_Visison=Weights_df.loc[(Weights_df["Segment"]=="Physical status") & (Weights_df["Variable"]=="Visison")]
Weights_df_Visison['Visison']=Weights_df_Visison['Category'].str.strip()
display(Data_df)
display(Weights_df_Visison)
Data_df = pd.merge(Data_df, Weights_df_Visison, on="Visison", how="outer",suffixes=('', '_drop')).dropna(subset = ['S.N'])
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_PS_Visison']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==4)])
display(Data_df.loc[(Data_df['S.N']==4)][['Visison','Score_PS_Visison']])

display(Data_df.loc[(Data_df['S.N']==3)])
display(Data_df.loc[(Data_df['S.N']==3)][['Visison','Score_PS_Visison']])
display(Data_df[Data_df['S.N'].isna()])
display(Data_df.loc[(Data_df['S.N']==581)])
display(Data_df.loc[(Data_df['S.N']==581)][['Visison','Score_PS_Visison']])


#Other disability
Data_df['Other disability']=Data_df['Other disability'].str.strip()
Weights_df["Category"]=Weights_df["Category"].fillna('None').str.strip()
Weights_df["Variable"]=Weights_df["Variable"].fillna('None').str.strip()
Weights_df_Other_disability=Weights_df.loc[(Weights_df["Segment"]=="Physical status") & (Weights_df["Variable"]=="Other disability")]
Weights_df_Other_disability['Other disability']=Weights_df_Other_disability['Category'].str.strip()
display(Data_df)
display(Weights_df_Other_disability)
Data_df = pd.merge(Data_df, Weights_df_Other_disability, on="Other disability", how="outer",suffixes=('', '_drop')).dropna(subset = ['S.N'])
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_PS_Other_disability']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==4)])
display(Data_df.loc[(Data_df['S.N']==4)][['Other disability','Score_PS_Other_disability']])

display(Data_df.loc[(Data_df['S.N']==3)])
display(Data_df.loc[(Data_df['S.N']==3)][['Other disability','Score_PS_Other_disability']])
display(Data_df[Data_df['S.N'].isna()])
display(Data_df.loc[(Data_df['S.N']==581)])
display(Data_df.loc[(Data_df['S.N']==581)][['Other disability','Score_PS_Other_disability']])


Data_df_PS=Data_df
# Out:
# /var/folders/dl/226xlm_d0m76nf_1nrmrhwp80000gn/T/ipykernel_84005/1709923533.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Weights_df_able_to_drive['able to drive']=Weights_df_able_to_drive['Category'].str.strip()
#        S.N                   Name     ID Age group Sex  \
# 0    265.0  Frist_1 Last name_133  NM265  below 30   M
# 1    389.0  Frist_1 Last name_195  NM389  below 30   M
# 2    202.0  Frist_2 Last name_102  NM202     30-45   F
# 3    490.0  Frist_2 Last name_246  NM490     30-45   F
# 4    580.0  Frist_2 Last name_291  NM580      60 +   F
# ..     ...                    ...    ...       ...  ..
# 577  467.0  Frist_1 Last name_234  NM467     45-60   M
# 578  395.0  Frist_1 Last name_198  NM395     45-60   M
# ...

# %%
Data_df=Data_df_PS

#Workouts( Walking/ Exercise)
Data_df['Workouts( Walking/ Exercise)']=Data_df['Workouts( Walking/ Exercise)'].str.strip()
Weights_df["Category"]=Weights_df["Category"].fillna('None').str.strip()
Weights_df["Variable"]=Weights_df["Variable"].fillna('None').str.strip()
Weights_df_Exercise=Weights_df.loc[(Weights_df["Segment"]=="Lifestyle") & (Weights_df["Variable"]=="Workouts( Walking/ Exercise)")]
Weights_df_Exercise['Workouts( Walking/ Exercise)']=Weights_df_Exercise['Category'].str.strip()
display(Data_df)
display(Weights_df_Exercise)
Data_df = pd.merge(Data_df, Weights_df_Exercise, on="Workouts( Walking/ Exercise)", how="outer",suffixes=('', '_drop')).dropna(subset = ['S.N'])
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_LS_Exercise']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==4)])
display(Data_df.loc[(Data_df['S.N']==4)][['Workouts( Walking/ Exercise)','Score_LS_Exercise']])

display(Data_df.loc[(Data_df['S.N']==3)])
display(Data_df.loc[(Data_df['S.N']==3)][['Workouts( Walking/ Exercise)','Score_LS_Exercise']])
display(Data_df[Data_df['S.N'].isna()])
display(Data_df.loc[(Data_df['S.N']==581)])
display(Data_df.loc[(Data_df['S.N']==581)][['Workouts( Walking/ Exercise)','Score_LS_Exercise']])


#Drug abuse
Data_df['Drug abuse']=Data_df['Drug abuse'].str.strip()
display(Data_df['Drug abuse'])
Weights_df["Category"]=Weights_df["Category"].fillna('None').str.strip()
Weights_df["Variable"]=Weights_df["Variable"].fillna('None').str.strip()
Weights_df_Drug_abuse=Weights_df.loc[(Weights_df["Segment"]=="Lifestyle") & (Weights_df["Variable"]=="Drug abuse")]
Weights_df_Drug_abuse['Drug abuse']=Weights_df_Drug_abuse['Category'].str.strip()
display(Data_df)
display(Weights_df_Drug_abuse)
Data_df = pd.merge(Data_df, Weights_df_Drug_abuse, on="Drug abuse", how="outer",suffixes=('', '_drop')).dropna(subset = ['S.N'])
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_LS_Drug_abuse']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==4)])
display(Data_df.loc[(Data_df['S.N']==4)][['Drug abuse','Score_LS_Drug_abuse']])

display(Data_df.loc[(Data_df['S.N']==3)])
display(Data_df.loc[(Data_df['S.N']==3)][['Drug abuse','Score_LS_Drug_abuse']])
display(Data_df[Data_df['S.N'].isna()])
display(Data_df.loc[(Data_df['S.N']==581)])
display(Data_df.loc[(Data_df['S.N']==581)][['Drug abuse','Score_LS_Drug_abuse']])


#Smoking
Data_df['Smoking']=Data_df['Smoking'].str.strip()
Weights_df["Category"]=Weights_df["Category"].fillna('None').str.strip()
Weights_df["Variable"]=Weights_df["Variable"].fillna('None').str.strip()
Weights_df_Smoking=Weights_df.loc[(Weights_df["Segment"]=="Lifestyle") & (Weights_df["Variable"]=="Smoking")]
Weights_df_Smoking['Smoking']=Weights_df_Smoking['Category'].str.strip()
display(Data_df)
display(Weights_df_Smoking)
Data_df = pd.merge(Data_df, Weights_df_Smoking, on="Smoking", how="outer",suffixes=('', '_drop')).dropna(subset = ['S.N'])
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_LS_Smoking']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==4)])
display(Data_df.loc[(Data_df['S.N']==4)][['Smoking','Score_LS_Smoking']])

display(Data_df.loc[(Data_df['S.N']==3)])
display(Data_df.loc[(Data_df['S.N']==3)][['Smoking','Score_LS_Smoking']])
display(Data_df[Data_df['S.N'].isna()])
display(Data_df.loc[(Data_df['S.N']==581)])
display(Data_df.loc[(Data_df['S.N']==581)][['Smoking','Score_LS_Smoking']])
display(Data_df.loc[(Data_df['S.N']==6)])
display(Data_df.loc[(Data_df['S.N']==6)][['Smoking','Score_LS_Smoking']])


#Alcoholic
Data_df['Alcoholic']=Data_df['Alcoholic'].str.strip()
Weights_df["Category"]=Weights_df["Category"].fillna('None').str.strip()
Weights_df["Variable"]=Weights_df["Variable"].fillna('None').str.strip()
Weights_df_Alcoholic=Weights_df.loc[(Weights_df["Segment"]=="Lifestyle") & (Weights_df["Variable"]=="Alcoholic")]
Weights_df_Alcoholic['Alcoholic']=Weights_df_Alcoholic['Category'].str.strip()
display(Data_df)
display(Weights_df_Alcoholic)
Data_df = pd.merge(Data_df, Weights_df_Alcoholic, on="Alcoholic", how="outer",suffixes=('', '_drop')).dropna(subset = ['S.N'])
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_LS_Alcoholic']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==4)])
display(Data_df.loc[(Data_df['S.N']==4)][['Alcoholic','Score_LS_Alcoholic']])

display(Data_df.loc[(Data_df['S.N']==3)])
display(Data_df.loc[(Data_df['S.N']==3)][['Alcoholic','Score_LS_Alcoholic']])
display(Data_df[Data_df['S.N'].isna()])
display(Data_df.loc[(Data_df['S.N']==581)])
display(Data_df.loc[(Data_df['S.N']==581)][['Alcoholic','Score_LS_Alcoholic']])
display(Data_df.loc[(Data_df['S.N']==6)])
display(Data_df.loc[(Data_df['S.N']==6)][['Alcoholic','Score_LS_Alcoholic']])


#Professional hazards
Data_df['Professional hazards']=Data_df['Professional hazards'].str.strip()
Weights_df["Category"]=Weights_df["Category"].fillna('None').str.strip()
Weights_df["Variable"]=Weights_df["Variable"].fillna('None').str.strip()
Weights_df_Professional_hazards=Weights_df.loc[(Weights_df["Segment"]=="Lifestyle") & (Weights_df["Variable"]=="Professional hazards")]
Weights_df_Professional_hazards['Professional hazards']=Weights_df_Professional_hazards['Category'].str.strip()
display(Data_df)
display(Weights_df_Professional_hazards)
Data_df = pd.merge(Data_df, Weights_df_Professional_hazards, on="Professional hazards", how="outer",suffixes=('', '_drop')).dropna(subset = ['S.N'])
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_LS_Professional_hazards']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==4)])
display(Data_df.loc[(Data_df['S.N']==4)][['Professional hazards','Score_LS_Professional_hazards']])

display(Data_df.loc[(Data_df['S.N']==3)])
display(Data_df.loc[(Data_df['S.N']==3)][['Professional hazards','Score_LS_Professional_hazards']])
display(Data_df[Data_df['S.N'].isna()])
display(Data_df.loc[(Data_df['S.N']==581)])
display(Data_df.loc[(Data_df['S.N']==581)][['Professional hazards','Score_LS_Professional_hazards']])
display(Data_df.loc[(Data_df['S.N']==6)])
display(Data_df.loc[(Data_df['S.N']==6)][['Professional hazards','Score_LS_Professional_hazards']])

#Other factors

Data_df['Other factors']=Data_df['Other factors'].str.strip()
Weights_df["Category"]=Weights_df["Category"].fillna('None').str.strip()
Weights_df["Variable"]=Weights_df["Variable"].fillna('None').str.strip()
Weights_df_Other_factors=Weights_df.loc[(Weights_df["Segment"]=="Lifestyle") & (Weights_df["Variable"]=="Other factors")]
Weights_df_Other_factors['Other factors']=Weights_df_Other_factors['Category'].str.strip()
display(Data_df)
display(Weights_df_Other_factors)
Data_df = pd.merge(Data_df, Weights_df_Other_factors, on="Other factors", how="outer",suffixes=('', '_drop')).dropna(subset = ['S.N'])
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_LS_Other_factors']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==4)])
display(Data_df.loc[(Data_df['S.N']==4)][['Other factors','Score_LS_Other_factors']])

display(Data_df.loc[(Data_df['S.N']==2)])
display(Data_df.loc[(Data_df['S.N']==2)][['Other factors','Score_LS_Other_factors']])
display(Data_df[Data_df['S.N'].isna()])
display(Data_df.loc[(Data_df['S.N']==581)])
display(Data_df.loc[(Data_df['S.N']==581)][['Other factors','Score_LS_Other_factors']])
display(Data_df.loc[(Data_df['S.N']==6)])
display(Data_df.loc[(Data_df['S.N']==6)][['Other factors','Score_LS_Other_factors']])
# Out:
# /var/folders/dl/226xlm_d0m76nf_1nrmrhwp80000gn/T/ipykernel_84005/1627587811.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Weights_df_Exercise['Workouts( Walking/ Exercise)']=Weights_df_Exercise['Category'].str.strip()
#        S.N                   Name     ID Age group Sex  \
# 0    265.0  Frist_1 Last name_133  NM265  below 30   M
# 1    202.0  Frist_2 Last name_102  NM202     30-45   F
# 2    490.0  Frist_2 Last name_246  NM490     30-45   F
# 3    580.0  Frist_2 Last name_291  NM580      60 +   F
# 4    274.0  Frist_2 Last name_138  NM274     30-45   F
# ..     ...                    ...    ...       ...  ..
# 577  413.0  Frist_1 Last name_207  NM413  below 30   M
# 578  557.0  Frist_1 Last name_279  NM557  below 30   M
# ...

# %%
#Awareness level

Data_df['Awareness level']=Data_df['Awareness level'].str.strip().replace("Y","High").replace("N","Low")
Weights_df["Category"]=Weights_df["Category"].fillna('None').str.strip()
Weights_df["Variable"]=Weights_df["Variable"].fillna('None').str.strip()
Weights_df_Awareness_level=Weights_df.loc[(Weights_df["Segment"]=="Social factors") & (Weights_df["Variable"]=="Awareness level")]
Weights_df_Awareness_level['Awareness level']=Weights_df_Awareness_level['Category'].str.strip()
display(Data_df)
display(Weights_df_Awareness_level)
Data_df = pd.merge(Data_df, Weights_df_Awareness_level, on="Awareness level", how="outer",suffixes=('', '_drop')).dropna(subset = ['S.N'])
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_SF_Awareness_level']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==4)])
display(Data_df.loc[(Data_df['S.N']==4)][['Awareness level','Score_SF_Awareness_level']])

display(Data_df.loc[(Data_df['S.N']==2)])
display(Data_df.loc[(Data_df['S.N']==2)][['Awareness level','Score_SF_Awareness_level']])
display(Data_df[Data_df['S.N'].isna()])
display(Data_df.loc[(Data_df['S.N']==581)])
display(Data_df.loc[(Data_df['S.N']==581)][['Awareness level','Score_SF_Awareness_level']])
display(Data_df.loc[(Data_df['S.N']==6)])
display(Data_df.loc[(Data_df['S.N']==6)][['Awareness level','Score_SF_Awareness_level']])


#Social media activity

Data_df['Social media activity']=Data_df['Social media activity'].str.strip().replace("Y","High").replace("N","Low")
Weights_df["Category"]=Weights_df["Category"].fillna('None').str.strip()
Weights_df["Variable"]=Weights_df["Variable"].fillna('None').str.strip()
Weights_df_Social_media_activity=Weights_df.loc[(Weights_df["Segment"]=="Social factors") & (Weights_df["Variable"]=="Social media activity")]
Weights_df_Social_media_activity['Social media activity']=Weights_df_Social_media_activity['Category'].str.strip()
display(Data_df)
display(Weights_df_Awareness_level)
Data_df = pd.merge(Data_df, Weights_df_Social_media_activity, on="Social media activity", how="outer",suffixes=('', '_drop')).dropna(subset = ['S.N'])
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_SF_Social_media_activity']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==4)])
display(Data_df.loc[(Data_df['S.N']==4)][['Social media activity','Score_SF_Social_media_activity']])

display(Data_df.loc[(Data_df['S.N']==2)])
display(Data_df.loc[(Data_df['S.N']==2)][['Social media activity','Score_SF_Social_media_activity']])
display(Data_df[Data_df['S.N'].isna()])
display(Data_df.loc[(Data_df['S.N']==581)])
display(Data_df.loc[(Data_df['S.N']==581)][['Social media activity','Score_SF_Social_media_activity']])
display(Data_df.loc[(Data_df['S.N']==6)])
display(Data_df.loc[(Data_df['S.N']==6)][['Social media activity','Score_SF_Social_media_activity']])

#Peer group influence

Data_df['Peer group influence']=Data_df['Peer group influence'].str.strip().replace("Y","High").replace("N","Low")
Weights_df["Category"]=Weights_df["Category"].fillna('None').str.strip()
Weights_df["Variable"]=Weights_df["Variable"].fillna('None').str.strip()
Weights_df_Peer_group_influence=Weights_df.loc[(Weights_df["Segment"]=="Social factors") & (Weights_df["Variable"]=="Peer group influence")]
Weights_df_Peer_group_influence['Peer group influence']=Weights_df_Peer_group_influence['Category'].str.strip()
display(Data_df)
display(Weights_df_Peer_group_influence)
Data_df = pd.merge(Data_df, Weights_df_Peer_group_influence, on="Peer group influence", how="outer",suffixes=('', '_drop')).dropna(subset = ['S.N'])
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_SF_Peer_group_influence']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==4)])
display(Data_df.loc[(Data_df['S.N']==4)][['Peer group influence','Score_SF_Peer_group_influence']])

display(Data_df.loc[(Data_df['S.N']==2)])
display(Data_df.loc[(Data_df['S.N']==2)][['Peer group influence','Score_SF_Peer_group_influence']])
display(Data_df[Data_df['S.N'].isna()])
display(Data_df.loc[(Data_df['S.N']==581)])
display(Data_df.loc[(Data_df['S.N']==581)][['Peer group influence','Score_SF_Peer_group_influence']])
display(Data_df.loc[(Data_df['S.N']==6)])
display(Data_df.loc[(Data_df['S.N']==6)][['Peer group influence','Score_SF_Peer_group_influence']])



#Other social activities

Data_df['Other social activities']=Data_df['Other social activities'].str.strip().replace("Y","High").replace("N","Low")
Weights_df["Category"]=Weights_df["Category"].fillna('None').str.strip()
Weights_df["Variable"]=Weights_df["Variable"].fillna('None').str.strip()
Weights_df_Other_social_activities=Weights_df.loc[(Weights_df["Segment"]=="Social factors") & (Weights_df["Variable"]=="Other social activities")]
Weights_df_Other_social_activities['Other social activities']=Weights_df_Other_social_activities['Category'].str.strip()
display(Data_df)
display(Weights_df_Peer_group_influence)
Data_df = pd.merge(Data_df, Weights_df_Other_social_activities, on="Other social activities", how="outer",suffixes=('', '_drop')).dropna(subset = ['S.N'])
#demo_age_scores_df=Data_df.merge(Weights_df_age, on='Age group', how='outer')[['S.N','Score_Weight']]                                    
display(Data_df)
Data_df.drop([col for col in Data_df.columns if 'drop' in col], axis=1, inplace=True)
Data_df['Score_SF_Other_social_activities']=Data_df['Score_Weight']
Data_df=Data_df.drop("Score_Weight",axis=1)
display(Data_df.count())

display(Data_df.loc[(Data_df['S.N']==4)])
display(Data_df.loc[(Data_df['S.N']==4)][['Other social activities','Score_SF_Other_social_activities']])

display(Data_df.loc[(Data_df['S.N']==2)])
display(Data_df.loc[(Data_df['S.N']==2)][['Other social activities','Score_SF_Other_social_activities']])
display(Data_df[Data_df['S.N'].isna()])
display(Data_df.loc[(Data_df['S.N']==581)])
display(Data_df.loc[(Data_df['S.N']==581)][['Other social activities','Score_SF_Other_social_activities']])
display(Data_df.loc[(Data_df['S.N']==6)])
display(Data_df.loc[(Data_df['S.N']==6)][['Other social activities','Score_SF_Other_social_activities']])
# Out:
# /var/folders/dl/226xlm_d0m76nf_1nrmrhwp80000gn/T/ipykernel_84005/1445766194.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Weights_df_Awareness_level['Awareness level']=Weights_df_Awareness_level['Category'].str.strip()
#        S.N                   Name     ID Age group Sex  \
# 0    265.0  Frist_1 Last name_133  NM265  below 30   M
# 1    202.0  Frist_2 Last name_102  NM202     30-45   F
# 2    490.0  Frist_2 Last name_246  NM490     30-45   F
# 3    580.0  Frist_2 Last name_291  NM580      60 +   F
# 4    274.0  Frist_2 Last name_138  NM274     30-45   F
# ..     ...                    ...    ...       ...  ..
# 577   29.0   Frist_1 Last name_15  NM029  below 30   M
# 578  573.0  Frist_1 Last name_287  NM573  below 30   M
# ...

# %%
print(Data_df.columns.tolist())
# Out:
# ['S.N', 'Name', 'ID', 'Age group', 'Sex', 'Status (Single/ partner)', 'Residence Zip Code', 'Score_Demo', 'Occupation', 'Own House', 'Own Car', 'FBP Level', 'Score_Fin', 'Family History', 'Annual Wellness vists', 'Known conditions', '# of Provider visist YTD', 'Score_Medical_History', 'Past medications', 'Last refill date', 'Refill due date', 'Formulary visist YTD', 'Days of Therapy missed', 'Score_Medication_History', '# of gaps prior year', '# of gaps  closed prior year', '# of gaps open prior year', '# of gaps current year', '# of gaps closed current year', '# of gaps open current year', 'able to drive', 'can walk long distance', 'Dental', 'Visison', 'Other disability', 'Score_Physical_Status', 'Workouts( Walking/ Exercise)', 'Alcoholic', 'Smoking', 'Professional hazards', 'Drug abuse', 'Other factors', 'Score_Lifestyle', 'Awareness level', 'Social media activity', 'Social media influence', 'Peer group influence', 'Other social activities', 'Score_Social_Factors', 'Segment_x', 'Va
# ...

# %%
result_df=Data_df[['S.N', 'Name', 'ID', 'Age group', 'Sex', 'Status (Single/ partner)', 'Residence Zip Code', 'Score_Demo', 'Occupation', 'Own House', 'Own Car', 'FBP Level', 'Score_Fin', 'Family History', 'Annual Wellness vists', 'Known conditions', '# of Provider visist YTD', 'Score_Medical_History', 'Past medications', 'Last refill date', 'Refill due date', 'Formulary visist YTD', 'Days of Therapy missed', 'Score_Medication_History', '# of gaps prior year', '# of gaps  closed prior year', '# of gaps open prior year', '# of gaps current year', '# of gaps closed current year', '# of gaps open current year', 'able to drive', 'can walk long distance', 'Dental', 'Visison', 'Other disability', 'Score_Physical_Status', 'Workouts( Walking/ Exercise)', 'Alcoholic', 'Smoking', 'Professional hazards', 'Drug abuse', 'Other factors', 'Score_Lifestyle', 'Awareness level', 'Social media activity', 'Social media influence', 'Peer group influence', 'Other social activities', 'Score_Social_Factors','Score_Demo_Age','Score_Demo_Sex','Score_Demo_Status','Score_Demo_Zip', 'Score_Fin_Occupation', 'Score_Fin_Own_House', 'Score_Fin_Own_Car', 'FBP_Level', 'Score_Fin_FBP_Level', 'Score_MH_Past_medications', 'Score_MH_Formulary_visist_YTD', 'Score_MH_Therapy_missed', 'Score_MH_Family_History', 'Score_MedH_Annual_Wellness_vists', 'Score_MedH_Known_conditions', 'Score_MedH_Provider_visists_YTD', 'Score_PS_able_to_drive', 'Score_PS_can_walk', 'Score_PS_Dental', 'Score_PS_Visison', 'Score_PS_Other_disability', 'Score_LS_Exercise', 'Score_LS_Drug_abuse', 'Score_LS_Smoking', 'Score_LS_Alcoholic', 'Score_LS_Professional_hazards', 'Score_LS_Other_factors', 'Score_SF_Awareness_level', 'Score_SF_Social_media_activity', 'Score_SF_Peer_group_influence', 'Score_SF_Other_social_activities']]
result_df['Score_Demo']=result_df['Score_Demo_Age']+result_df['Score_Demo_Sex']+result_df['Score_Demo_Status']+result_df['Score_Demo_Zip']
result_df['Score_Fin']=result_df['Score_Fin_Occupation']+result_df['Score_Fin_Own_House']+result_df['Score_Fin_Own_Car']+result_df['Score_Fin_FBP_Level'].fillna(0)
result_df['Score_Medical_History']=result_df['Score_MH_Past_medications']+result_df['Score_MH_Formulary_visist_YTD']+result_df['Score_MH_Therapy_missed']+result_df['Score_MH_Family_History']
result_df['Score_Medication_History']=result_df['Score_MedH_Annual_Wellness_vists']+result_df['Score_MedH_Known_conditions']+result_df['Score_MedH_Provider_visists_YTD']
result_df['Score_Physical_Status']=result_df['Score_PS_able_to_drive']+result_df['Score_PS_can_walk']+result_df['Score_PS_Dental']+result_df['Score_PS_Visison']+result_df['Score_PS_Other_disability']
result_df['Score_Lifestyle']=result_df['Score_LS_Exercise']+result_df['Score_LS_Exercise']+result_df['Score_LS_Smoking']+result_df['Score_LS_Alcoholic']+result_df['Score_LS_Professional_hazards']+result_df['Score_LS_Other_factors']
result_df['Score_Social_Factors']=result_df['Score_SF_Awareness_level']+result_df['Score_SF_Social_media_activity']+result_df['Score_SF_Peer_group_influence']+result_df['Score_SF_Other_social_activities']





result_df.to_csv('/Users/rajeshwarrao/Downloads/Result_Scores_Dataset.csv',sep=',')
# Out:
# /var/folders/dl/226xlm_d0m76nf_1nrmrhwp80000gn/T/ipykernel_84005/2828002893.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['Score_Demo']=result_df['Score_Demo_Age']+result_df['Score_Demo_Sex']+result_df['Score_Demo_Status']+result_df['Score_Demo_Zip']
# /var/folders/dl/226xlm_d0m76nf_1nrmrhwp80000gn/T/ipykernel_84005/2828002893.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# !jupyter --config-dir
# Out:
# /Users/rajeshwarrao/.jupyter

# %%
# !jupyter --paths
# !ls -lhrt Scoring*
# !pwd
# Out:
# config:
#     /Users/rajeshwarrao/.jupyter
#     /Users/rajeshwarrao/opt/anaconda3/etc/jupyter
#     /usr/local/etc/jupyter
#     /etc/jupyter
# data:
#     /Users/rajeshwarrao/Library/Jupyter
#     /Users/rajeshwarrao/opt/anaconda3/share/jupyter
#     /usr/local/share/jupyter
#     /usr/share/jupyter
# runtime:
#     /Users/rajeshwarrao/Library/Jupyter/runtime
# -rw-r--r--  1 rajeshwarrao  staff   1.5M Sep 16 22:03 Scoring.ipynb
# /Users/rajeshwarrao/opt/anaconda3/bin

# %%
from matplotlib import pyplot
from pandas import read_csv
from pandas.plotting import scatter_matrix
path = r"/Users/rajeshwarrao/Downloads/Result_Scores_Dataset.csv"


names = ['Score_Demo']

data = read_csv(path,sep=",", header=1,names=names)
scatter_matrix(data)
pyplot.show()
# Out:
# /Users/rajeshwarrao/opt/anaconda3/envs/tf/lib/python3.10/site-packages/pandas/plotting/_matplotlib/misc.py:92: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(boundaries_list[i])

# %%
from matplotlib import pyplot
from pandas import read_csv
data.plot(kind='box', subplots=True, layout=(3,3), sharex=False,sharey=False)
pyplot.show()

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'Score_Demo'}>]], dtype=object)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data.describe()
# Out:
#        Score_Demo
# count       581.0
# mean         10.0
# std           0.0
# min          10.0
# 25%          10.0
# 50%          10.0
# 75%          10.0
# max          10.0

# %%
Data_df.plot(x='Score_Demo', y='Score_Social_Factors', kind='bar')
plt.show()

# Using seaborn
sns.barplot(x='Score_Demo', y='Score_Social_Factors', data=Data_df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 5
#       2 plt.show()
#       4 # Using seaborn
# ----> 5 sns.barplot(x='Score_Demo', y='Score_Social_Factors', data=Data_df)
#       6 plt.show()
#
# File ~/opt/anaconda3/envs/tf/lib/python3.10/site-packages/seaborn/categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
#    2758                       width, errcolor, errwidth, capsize, dodge)
#    2760 if ax is None:
# ...

# %%
Data_df.set_index('Score_Demo')['Score_Social_Factors'].plot.pie(autopct='%1.1f%%')
plt.show()

# %%
# Using seaborn
sns.countplot(Data_df)
plt.show()

# %%
# !which python

# %%
import pandas as pd
import numpy as np

# Load your small dataset into a Pandas DataFrame
original_data = result_df
original_data.astype(str)

# Number of synthetic data points you want to generate
num_synthetic_points = 10000

# Generate synthetic data
synthetic_data = []

for _ in range(num_synthetic_points):
    # Randomly select an index from the original data
    random_index = np.random.randint(len(original_data))
    
    # Get the selected row from the original data
    original_row = original_data.iloc[random_index]
    #print(original_row)
    
    # Generate synthetic values by adding noise to the original values
    synthetic_values = original_row.astype(str) + np.random.normal(scale=0.1, size=len(original_row)).astype(str)
    
    # Append the synthetic values to the synthetic_data list
    synthetic_data.append(synthetic_values)

# Create a DataFrame from the synthetic_data list
synthetic_df = pd.DataFrame(synthetic_data, columns=original_data.columns)

# Concatenate the original data with the synthetic data
combined_data = pd.concat([original_data, synthetic_df], ignore_index=True)
combined_data.head()
combined_data.describe()

# %%
combined_data.tail()

# %%
combined_data.to_csv("/Users/rajeshwarrao/Downloads/generated_data.csv")

# %%
Data_df.describe()
display(Data_df)
print(Data_df.columns.tolist())

# %%
selected_columns = ['S.N', 'Name', 'ID','Score_Demo','Score_Fin','Score_Medical_History','Score_Medication_History','Score_Physical_Status','Score_Lifestyle']
Data_Scores1_df=Data_df[selected_columns]
display(Data_Scores1_df)
Data_Scores1_df.describe()
