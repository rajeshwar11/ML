# %%
import csv
import numpy as np
with open("/Downloads/Housing.csv") as housing:
    data = list(csv.reader(housing,delimiter=","))
print(data)
data = np.array(data)
print(data)
# Out:
# [['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'parking', 'prefarea', 'furnishingstatus'], ['13300000', '7420', '4', '2', '3', 'yes', 'no', 'no', 'no', 'yes', '2', 'yes', 'furnished'], ['12250000', '8960', '4', '4', '4', 'yes', 'no', 'no', 'no', 'yes', '3', 'no', 'furnished'], ['12250000', '9960', '3', '2', '2', 'yes', 'no', 'yes', 'no', 'no', '2', 'yes', 'semi-furnished'], ['12215000', '7500', '4', '2', '2', 'yes', 'no', 'yes', 'no', 'yes', '3', 'yes', 'furnished'], ['11410000', '7420', '4', '1', '2', 'yes', 'yes', 'yes', 'no', 'yes', '2', 'no', 'furnished'], ['10850000', '7500', '3', '3', '1', 'yes', 'no', 'yes', 'no', 'yes', '2', 'yes', 'semi-furnished'], ['10150000', '8580', '4', '3', '4', 'yes', 'no', 'no', 'no', 'yes', '2', 'yes', 'semi-furnished'], ['10150000', '16200', '5', '3', '2', 'yes', 'no', 'no', 'no', 'no', '0', 'no', 'unfurnished'], ['9870000', '8100', '4', '1', '2', 'yes', 'yes', 'yes'
# ...

# %%
price_area=data[:,[0,1]][1:]
print(price_area)
# Out:
# [['13300000' '7420']
#  ['12250000' '8960']
#  ['12250000' '9960']
#  ...
#  ['1750000' '3620']
#  ['1750000' '2910']
#  ['1750000' '3850']]

# %%
with open("/Users/rajeshwarrao/Downloads/Housing.csv") as h:
    data1=list(csv.reader(h, delimiter=","))
print(data[:,1])
# Out:
# ['area' '7420' '8960' '9960' '7500' '7420' '7500' '8580' '16200' '8100'
#  '5750' '13200' '6000' '6550' '3500' '7800' '6000' '6600' '8500' '4600'
#  '6420' '4320' '7155' '8050' '4560' '8800' '6540' '6000' '8875' '7950'
#  '5500' '7475' '7000' '4880' '5960' '6840' '7000' '7482' '9000' '6000'
#  '6000' '6550' '6360' '6480' '6000' '6000' '6000' '6000' '6600' '4300'
#  '7440' '7440' '6325' '6000' '5150' '6000' '6000' '11440' '9000' '7680'
#  '6000' '6000' '8880' '6240' '6360' '11175' '8880' '13200' '7700' '6000'
#  '12090' '4000' '6000' '5020' '6600' '4040' '4260' '6420' '6500' '5700'
#  '6000' '6000' '4000' '10500' '6000' '3760' '8250' '6670' '3960' '7410'
#  '8580' '5000' '6750' '4800' '7200' '6000' '4100' '9000' '6400' '6600'
#  '6000' '6600' '5500' '5500' '6350' '5500' '4500' '5450' '6420' '3240'
#  '6615' '6600' '8372' '4300' '9620' '6800' '8000' '6900' '3700' '6420'
#  '7020' '6540' '7231' '6254' '7320' '6525' '15600' '7160' '6500' '5500'
# ...

# %%
import matplotlib.pyplot as plt
plt.style.use('/Users/rajeshwarrao/Downloads/Files/home/jovyan/work/deeplearning.mplstyle')
x_train = data[1:,1].astype("float64")/1000
#print(x_train)
y_train = data[1:,0].astype("float64")/1000
#print(y_train)
print(f"x_train.shape: {x_train.shape}")
m=x_train.shape[0]
print(f"Number of traning examples is : {m}")
# Out:
# x_train.shape: (545,)
# Number of traning examples is : 545

# %%
m= len(x_train)
print(f"Number of traning examples are : {m}")
# Out:
# Number of traning examples are : 545

# %%
plt.scatter(x_train,y_train,marker='x',c='r')
plt.title("Housing Prices")
plt.ylabel('Price (in 1000s of dollars)')
plt.xlabel('Size (1000 sqft)')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt
from lab_utils_uni import plt_intuition, plt_stationary, plt_update_onclick,soup_bowl
plt.style.use('./deeplearning.mplstyle')

# %%
def compute_cost(x,y,w,b):
    m=x.shape[0]
    cost_sum=0
    for i in range(m):
        f_wb=w*x[i]+b
        cost=(f_wb-y[i])**2
        cost_sum=cost_sum+cost
    total_cost=(1/(2*m))*cost_sum
    return total_cost

# %%
plt_intuition(x_train[:300],y_train[:300])
# Out:
# interactive(children=(IntSlider(value=150, description='w', max=400, step=10), Output()), _dom_classes=('widge…

# %%
plt.close('all') 
fig, ax, dyn_items = plt_stationary(x_train[:200], y_train[:200])
updater = plt_update_onclick(fig, ax, x_train[:200], y_train[:200], dyn_items)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
